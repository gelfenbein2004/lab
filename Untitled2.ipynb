# %% [markdown]
# <a href="https://colab.research.google.com/github/gelfenbein2004/lab/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# найти массу
#ДАНО
import numpy as np
import matplotlib.pyplot as plt
T=np.linspace(0,400,100)
P=101325
V=64
R=8.314
#решение номер 1
M=0.016
m=(P*V*M)/(R*T)
plt.plot(T,m)
plt.show()
print(m)
# Out:
# <ipython-input-29-758f308bc7c0>:11: RuntimeWarning: divide by zero encountered in true_divide
#   m=(P*V*M)/(R*T)
# [          inf 3088.7428434  1544.3714217  1029.5809478   772.18571085
#   617.74856868  514.7904739   441.24897763  386.09285542  343.19364927
#   308.87428434  280.79480395  257.39523695  237.59560334  220.62448881
#   205.91618956  193.04642771  181.69075549  171.59682463  162.56541281
#   154.43714217  147.08299254  140.39740197  134.2931671   128.69761847
#   123.54971374  118.79780167  114.39788309  110.31224441  106.50837391
#   102.95809478   99.63686592   96.52321386   93.59826798   90.84537775
#    88.24979553   85.79841232   83.47953631   81.28270641   79.19853445
#    77.21857108   75.3351913    73.54149627   71.83122892   70.19870099
#    68.63872985   67.14658355   65.71793284   64.34880924   63.03556823
#    61.77485687   60.56358516   59.39890083   58.27816686   57.19894154
#    56.15896079   55.1561222    54.18847094   53.25418696   52.35157362
# ...

# %%
pip install CoolProp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 71.1 MB/s eta 0:00:00
# ...

# %%
import CoolProp.CoolProp as ct
import numpy as np
import matplotlib.pyplot as plt
t=np.linspace(0,400,500)
Fluid_name="CH4"
V=64
p=101325
M=0.016
d=ct.PropsSI("D","P",p,"T",t,Fluid_name)
m=d*V
plt.plot(t,m,'r')
plt.grid()
T=np.linspace(0,400,100)
R=8.314
m=(p*V*M)/(R*T)
plt.scatter(373,47.5)
plt.plot(T,m)
plt.show()
# Out:
# <ipython-input-41-0d4000f794f5>:15: RuntimeWarning: divide by zero encountered in true_divide
#   m=(p*V*M)/(R*T)
